# %% [markdown]
# #Cognifyz Technologies Task
# 1. Know Your Data
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Load Dataset

# %%
df = pd.read_csv(r'C:\Users\91738\Downloads\Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# #Dataset Rows & Columns count

# %%
rows, cols = df.shape
print(f'There are {rows} rows and {cols} columns in the dataset.')
# Out:
# There are 9551 rows and 21 columns in the dataset.

# %% [markdown]
# Duplicate Values

# %%
duplicate_rows = df.duplicated().sum()
print(f'There are {duplicate_rows} duplicate_rows in the dataset')
# Out:
# There are 0 duplicate_rows in the dataset

# %% [markdown]
# Missing Values/Null Values

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
null_values = df.isna()
null_columns = null_values.any()

null_columns = df.columns[null_columns].tolist()
print(null_columns)
# Out:
# ['Cuisines']

# %% [markdown]
# Visualizing the missing values

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.5.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.26.2)
# Requirement already satisfied: matplotlib in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (3.8.2)
# Requirement already satisfied: seaborn in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (0.13.0)
# Requirement already satisfied: scipy in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.11.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pillow>=8 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (10.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn->missingno) (2.1.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\91738\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\91738\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Visualizing the missing values
import missingno as msno

#Visualise the missing values as a matrix
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# 2. Understanding Your Variables

# %%
columns = df.columns
print('"Columns in the dataset"')
for column in columns:
    print(column)
# Out:
# "Columns in the dataset"
# Restaurant ID
# Restaurant Name
# Country Code
# City
# Address
# Locality
# Locality Verbose
# Longitude
# Latitude
# Cuisines
# Average Cost for two
# Currency
# Has Table booking
# Has Online delivery
# Is delivering now
# Switch to order menu
# Price range
# Aggregate rating
# Rating color
# Rating text
# Votes

# %% [markdown]
# Dataset Describe

# %%
summary = df.describe()
print(summary)
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# 3. Data Wrangling

# %%
print(df.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
print(df.dtypes)
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
pd.reset_option('display.max_rows')

# %%
pd.reset_option('display.max_rows')

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# 4. Data Vizualization

# %% [markdown]
# Level 1 - Task 1 : "Top Cuisines"

# %% [markdown]
# Determine the top three most common cuisines in the dataset.

# %% [markdown]
# Calculate the percentage of restaurants that serve each of the top cuisines.

# %%
#Determine the top three most common cuisines in the dataset.
top_cuisines = df['Cuisines'].value_counts().nlargest(3).index.tolist()
print("Top Three Cuisines:")
for index, Cuisines in enumerate(top_cuisines, 1):
    print(f"{index}. {Cuisines}")
    
    # Calculate the total count of each cuisine
cuisine_counts = df['Cuisines'].value_counts()

# Initialize a dictionary to store the percentage of each top cuisine
percentage_cuisine = {}

# Calculate the percentage for each top cuisine
for cuisine in top_cuisines:
    total_restaurants = len(df)
    cuisine_count = cuisine_counts.get(cuisine, 0)  # Get the count of restaurants serving this cuisine
    percentage = (cuisine_count / total_restaurants) * 100
    percentage_cuisine[cuisine] = percentage

# Print the percentage of restaurants serving each top cuisine
print("\nPercentage of Restaurants Serving Each Top Cuisine:")
for cuisine, percentage in percentage_cuisine.items():
    print(f"- {cuisine}: {percentage:.2f}%")
# Out:
# Top Three Cuisines:
# 1. North Indian
# 2. North Indian, Chinese
# 3. Chinese
#
# Percentage of Restaurants Serving Each Top Cuisine:
# - North Indian: 9.80%
# - North Indian, Chinese: 5.35%
# - Chinese: 3.71%

# %% [markdown]
# Level 1 - Task 2 : "City Analysis"

# %% [markdown]
# Identify the city with the highest number of restaurants in the dataset.

# %% [markdown]
# Calculate the average rating for restaurants in each city.

# %% [markdown]
# Determine the city with the highest average rating.

# %%
# Identify the city with the highest number of restaurants
top_city_restaurants = df['City'].value_counts().idxmax()
print(f"The city with the highest number of restaurants is: {top_city_restaurants}")

# Calculate the average rating for restaurants in each city
average_rating_per_city = df.groupby('City')['Aggregate rating'].mean()

# Determine the city with the highest average rating
city_highest_avg_rating = average_rating_per_city.idxmax()
highest_avg_rating = average_rating_per_city.max()

print(f"\nThe city with the highest average rating is: {city_highest_avg_rating}")
print(f"\nThe average rating in that city is: {highest_avg_rating:.2f}")
# Out:
# The city with the highest number of restaurants is: New Delhi
#
# The city with the highest average rating is: Inner City
#
# The average rating in that city is: 4.90

# %% [markdown]
# Level 1 - Task 3 : "Price Range Distribution"

# %% [markdown]
# Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.

# %% [markdown]
# Calculate the percentage of restaurants in each price range category.

# %%
import matplotlib.pyplot as plt

# Define colors for the bars
colors = ['skyblue', 'lightgreen', 'lightcoral', 'orange']

# Plotting the bar chart for price ranges
plt.figure(figsize=(10, 6))
price_range_counts = df['Price range'].value_counts().sort_index()
plt.bar(price_range_counts.index, price_range_counts.values, color=colors)

# Adding title and labels
plt.title('Price Range Distribution Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Show the plot
plt.show()

# Calculate the percentage of restaurants in each price range category
price_range_percentage = (df['Price range'].value_counts(normalize=True) * 100).sort_index()
print("\nPercentage of Restaurants in Each Price Range Category:")
for price_range, percentage in price_range_percentage.items():
    print(f"- Price Range {price_range}: {percentage:.2f}%")
# Out:
# Percentage of Restaurants in Each Price Range Category:
# - Price Range 1: 46.53%
# - Price Range 2: 32.59%
# - Price Range 3: 14.74%
# - Price Range 4: 6.14%

# %% [markdown]
# Level 1 - Task 4 : "Online Delivery"

# %% [markdown]
# Determine the percentage of restaurants that offer online delivery.

# %% [markdown]
# Compare the average ratings of restaurants with and without online delivery.

# %%
# Determine the percentage of restaurants that offer online delivery
online_delivery_percentage = (df['Has Online delivery'].value_counts(normalize=True) * 100).get('Yes', 0)
print(f"Percentage of Restaurants Offering Online Delivery: {online_delivery_percentage:.2f}%")

# Task 2: Compare the average ratings of restaurants with and without online delivery
average_rating_with_delivery = df[df['Has Online delivery'] == 'Yes']['Aggregate rating'].mean()
average_rating_without_delivery = df[df['Has Online delivery'] == 'No']['Aggregate rating'].mean()

print(f"\nAverage Rating of Restaurants with Online Delivery: {average_rating_with_delivery:.2f}")
print(f"\nAverage Rating of Restaurants without Online Delivery: {average_rating_without_delivery:.2f}")
# Out:
# Percentage of Restaurants Offering Online Delivery: 25.66%
#
# Average Rating of Restaurants with Online Delivery: 3.25
#
# Average Rating of Restaurants without Online Delivery: 2.47

# %% [markdown]
# Level 2 - Task 1 : "Restaurant Ratings"

# %% [markdown]
# Analyze the distribution of aggregate ratings and determine the most common rating range.

# %% [markdown]
# Calculate the average number of votes received by restaurants.

# %%
# Analyze the distribution of aggregate ratings and determine the most common rating range
rating_counts = df['Aggregate rating'].value_counts().sort_index(ascending=False)
most_common_rating_range = rating_counts.idxmax()

print(f"Most Common Rating Range: {most_common_rating_range}")

# Calculate the average number of votes received by restaurants
average_votes = df['Votes'].mean()

print(f"\nAverage Number of Votes Received by Restaurants: {average_votes:.2f}")
# Out:
# Most Common Rating Range: 0.0
#
# Average Number of Votes Received by Restaurants: 156.91

# %% [markdown]
# Level 2 - Task 2 : "Cuisine Combination"

# %% [markdown]
# Identify the most common combinations of cuisines in the dataset.

# %% [markdown]
# Determine if certain cuisine combinations tend to have higher ratings.

# %%
import pandas as pd

# Extract unique cuisine combinations
unique_combinations = df['Cuisines'].str.split(', ').explode().unique()

# Create lists to store data
combination_data = []

# Iterate over unique combinations and calculate counts and average ratings
for combination in unique_combinations:
    try:
        combination_filter = df['Cuisines'].apply(lambda x: combination.lower() in x.lower() if pd.notna(x) else False)
        combination_count = combination_filter.sum()
        average_rating = df.loc[combination_filter, 'Aggregate rating'].mean()

        combination_data.append({'Combination': combination, 'Count': combination_count, 'Average Rating': average_rating})
    except AttributeError:
        continue

# Create DataFrame from the list
combination_counts = pd.DataFrame(combination_data)

# Sort the DataFrame by count in descending order
combination_counts = combination_counts.sort_values(by='Count', ascending=False)

print("Most Common Cuisine Combinations:")
print(combination_counts[['Combination', 'Count']])

print("\nAverage Ratings for Cuisine Combinations:")
print(combination_counts[['Combination', 'Average Rating']])
# Out:
# Most Common Cuisine Combinations:
#         Combination  Count
# 6            Indian   4259
# 81     North Indian   3960
# 9           Chinese   2733
# 19        Fast Food   1987
# 82          Mughlai    994
# ..              ...    ...
# 131  Fish and Chips      1
# 120         Malwani      1
# 121  Cuisine Varies      1
# 65            Irish      1
# 144          B�_rek      1
#
# [145 rows x 2 columns]
#
# Average Ratings for Cuisine Combinations:
#         Combination  Average Rating
# 6            Indian        2.525053
# 81     North Indian        2.510455
# 9           Chinese        2.620234
# 19        Fast Food        2.563966
# 82          Mughlai        2.612575
# ..              ...             ...
# 131  Fish and Chips        4.300000
# 120         Malwani        3.500000
# 121  Cuisine Varies        0.000000
# 65            Irish        4.300000
# 144          B�_rek        4.700000
#
# [145 rows x 2 columns]

# %% [markdown]
# Level 2 - Task 3 : "Geographic Analysis"

# %% [markdown]
# Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %% [markdown]
# Identify any patterns or clusters of restaurants in specific areas.

# %%
import folium
from folium.plugins import MarkerCluster

# Filter out rows with missing latitude or longitude values
df = df.dropna(subset=['Latitude', 'Longitude'])

# Create a map centered around the average latitude and longitude
average_latitude = df['Latitude'].mean()
average_longitude = df['Longitude'].mean()
restaurant_map = folium.Map(location=[average_latitude, average_longitude], zoom_start=12)

# Create a MarkerCluster to group nearby markers
marker_cluster = MarkerCluster().add_to(restaurant_map)

# Add markers for each restaurant
for index, row in df.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']],
                  popup=row['Restaurant Name']).add_to(marker_cluster)

# Save the map as an HTML file or display it
restaurant_map.save('restaurant_map.html')
# restaurant_map  # Uncomment this line to display the map in Jupyter Notebook (may not work in all environments)

# %% [markdown]
# Level 2 - Task 4 : "Restaurant Chains"

# %% [markdown]
# Identify if there are any restaurant chains present in the dataset.

# %% [markdown]
# Analyze the ratings and popularity of different restaurant chains.

# %%
# Identify restaurant chains based on the 'Restaurant Name'
restaurant_chains = df['Restaurant Name'].value_counts()

# Filter out individual restaurants (considering chains with multiple locations)
chains = restaurant_chains[restaurant_chains > 1].index

# Create a DataFrame for restaurant chains
chain_df = df[df['Restaurant Name'].isin(chains)].copy()

# Analyze ratings and popularity of different restaurant chains
chain_analysis = chain_df.groupby('Restaurant Name').agg({
    'Aggregate rating': 'mean',
    'Votes': 'sum',
    'Average Cost for two': 'mean'
}).sort_values(by='Votes', ascending=False)

# Display the analysis
print("Restaurant Chains Analysis:")
print(chain_analysis)
# Out:
# Restaurant Chains Analysis:
#                            Aggregate rating  Votes  Average Cost for two
# Restaurant Name
# Barbeque Nation                    4.353846  28142           1498.076923
# AB's - Absolute Barbecues          4.825000  13400           1500.000000
# Big Chill                          4.475000  10853           1500.000000
# Farzi Cafe                         4.366667  10098           1516.666667
# Truffles                           3.950000   9682            550.000000
# ...                                     ...    ...                   ...
# Bikaner Misthan Bhandar            0.000000      0            250.000000
# Aap Ki Khatir                      0.000000      0            400.000000
# Street Cafe                        0.000000      0            300.000000
# Jyoti Sweets                       0.000000      0            200.000000
# Firangi Bake                       0.000000      0            300.000000
#
# [734 rows x 3 columns]

# %% [markdown]
# Level 3 - Task 2 : "Votes Analysis"

# %% [markdown]
# Identify the restaurants with the highest and lowest number of votes.

# %% [markdown]
# Analyze if there is a correlation between the number of votes and the rating of a restaurant.

# %%
# Identify restaurants with the highest and lowest number of votes
highest_votes_restaurant = df.loc[df['Votes'].idxmax()]
lowest_votes_restaurant = df.loc[df['Votes'].idxmin()]

print("Restaurant with the Highest Number of Votes:")
print(highest_votes_restaurant[['Restaurant Name', 'Votes', 'Aggregate rating']])

print("\nRestaurant with the Lowest Number of Votes:")
print(lowest_votes_restaurant[['Restaurant Name', 'Votes', 'Aggregate rating']])

# Analyze correlation between the number of votes and restaurant rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Votes', y='Aggregate rating', data=df)
plt.title('Correlation between Number of Votes and Restaurant Rating')
plt.xlabel('Number of Votes')
plt.ylabel('Aggregate Rating')
plt.show()

# Calculate correlation coefficient
correlation_coefficient = df['Votes'].corr(df['Aggregate rating'])
print(f"\nCorrelation Coefficient between Votes and Rating: {correlation_coefficient}")
# Out:
# Restaurant with the Highest Number of Votes:
# Restaurant Name      Toit
# Votes               10934
# Aggregate rating      4.8
# Name: 728, dtype: object
#
# Restaurant with the Lowest Number of Votes:
# Restaurant Name     Cantinho da Gula
# Votes                              0
# Aggregate rating                 0.0
# Name: 69, dtype: object
# Correlation Coefficient between Votes and Rating: 0.31369058419541146

# %% [markdown]
# Level 3 - Task 3 : "Price Range vs. Online Delivery and Table Booking"

# %% [markdown]
# Analyze if there is a relationship between the price range and the availability of online delivery and table booking.

# %% [markdown]
# Determine if higher-priced restaurants are more likely to offer these services.

# %%
# Check the unique values in the 'Price Range' column
print("Unique Price Range Values:", df['Price range'].unique())

# Replace the '$' signs in the 'Price Range' column with numeric values
df['Price range'] = df['Price range'].replace({'$': 1, '$$': 2, '$$$': 3, '$$$$': 4})

# Analyze the relationship between price range and online delivery
plt.figure(figsize=(12, 6))
sns.countplot(x='Price range', hue='Has Online delivery', data=df)
plt.title('Relationship between Price Range and Online Delivery')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()

# Analyze the relationship between price range and table booking
plt.figure(figsize=(12, 6))
sns.countplot(x='Price range', hue='Has Table booking', data=df)
plt.title('Relationship between Price Range and Table Booking')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()
# Out:
# Unique Price Range Values: [3 4 2 1]

# %%
# Replace the '$' signs in the 'Price Range' column with numeric values
df['Price range'] = df['Price range'].replace({'$': 1, '$$': 2, '$$$': 3, '$$$$': 4})

# Create subplots with two columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Analyze the relationship between price range and online delivery
sns.countplot(x='Price range', hue='Has Online delivery', data=df, ax=axes[0])
axes[0].set_title('Relationship between Price Range and Online Delivery')
axes[0].set_xlabel('Price Range')
axes[0].set_ylabel('Count')

# Analyze the relationship between price range and table booking
sns.countplot(x='Price range', hue='Has Table booking', data=df, ax=axes[1])
axes[1].set_title('Relationship between Price Range and Table Booking')
axes[1].set_xlabel('Price Range')
axes[1].set_ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
